# %% [markdown]
# # Tile: Why classical Ml
#
# Jaccard similarity : lack to identify the no of count and change in vector
#
#
# ## Cosine similarity:
# in coordinate systen and then see angle and find difference
# improved on jaccard and eucldien
#
# lack in weightage in the words or token in the sentence.
#
# ### To reduce this consine similarity limit:
#
#     ## TF-IBF:
#         when used log (natural) : computation time in reduced
#
#         we can use for loop for simple and small file only
#         but
#         we use KNN to  generate structural tree
#         used in very large file
